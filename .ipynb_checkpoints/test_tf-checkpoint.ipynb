# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

file_path = 'data/data_asset_choosed/487/subset_by_time/'
file_name = '35_speed_60_delete_new_info1.csv'
df_asset = pd.read_csv(file_path+file_name)

# %%
keys_data = ["average_speed","average_speed_60","time","distance"]
keys_prediction = ["fuel"]
# Out:
#            average_speed    average_speed_60  time distance
# 0
# 1                  126.0            85.33125   2.0       70
# 2      93.60000000000001            85.33125   3.0       78
# 3      75.60000000000001            85.33125   4.0       84
# 4      75.60000000000001            85.33125   4.0       84
# 5     60.480000000000004            85.33125   5.0       84
# 6                   79.2            85.33125   4.0       88
# 7       78.0923076923077            85.33125  13.0      282
# 8                  104.4            85.33125   3.0       87
# 9      80.10000000000001            85.33125   4.0       89
# 10                  83.7            85.33125   4.0       93
# 11                  90.0            85.33125   5.0      125
# 12     93.60000000000001            85.33125   3.0       78
# 13                  97.2            85.33125   5.0      135
# 14                 100.8            85.33125   5.0      140
# 15     91.71428571428571   92.17142857142858  21.0      535
# ...

# %%
batch_size = 128

graph = tf.Graph()
with graph.as_default():
